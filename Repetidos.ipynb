# %%
import pandas as pd
import numpy as np
import os
import csv
import urllib3

# %%
os.getcwd()
os.chdir('C:\\Users\\X268765\\Documents\\DQ\\Python')

# %%
repetidos=pd.read_csv('http://asset.nngg.corp:10000/links_logs/ac_santander/ImportExport/reporting/TRIM/REPETIDOS_MAD_20160816_20180817.csv',sep=';')
repetidos.to_csv('REPETIDOS_MAD_20160816_20180817.csv',sep=';',index=False)

# %%
repetidos[repetidos['MAX CONSECUTIVE REPETITIONS']>=20]
# Out:
#                        SYMBOL              DESCRIPTION  \
# 3070            ISS-PE-USD-3Y          ISS-PERU-USD-3Y
# 3083            ISS-PE-USD-5Y          ISS-PERU-USD-5Y
# 3088            ISS-NL-EUR-1Y   ISS-NETHERLANDS-EUR-1Y
# 3133            ISS-PE-USD-7Y          ISS-PERU-USD-7Y
# 3334  ISS-BONDCURVE-PL-PLN-7Y  ISS-BONDCURVE-PL-PLN-7Y
#
#                          LIST              ALIAS             CODE      FIELD  \
# 3070  MAD_CR_SOVEREIGN_SPREAD  ALIAS_AIRE_HS_MAD    ISS-PE-USD-3Y  EOD_CLOSE
# 3083  MAD_CR_SOVEREIGN_SPREAD  ALIAS_AIRE_HS_MAD    ISS-PE-USD-5Y  EOD_CLOSE
# 3088  MAD_CR_SOVEREIGN_SPREAD  ALIAS_AIRE_HS_MAD    ISS-NL-EUR-1Y  EOD_CLOSE
# 3133  MAD_CR_SOVEREIGN_SPREAD  ALIAS_AIRE_HS_MAD    ISS-PE-USD-7Y  EOD_CLOSE
# 3334   MAD_CR_ISS_BOND_SPREAD  ALIAS_AIRE_HS_MAD  ISS-PL-N-PLN-7Y  EOD_CLOSE
#
#      COORDINATES  NRECORDS  TOTAL REPETITIONS  MAX CONSECUTIVE REPETITIONS  \
# 3070         NaN       520                 37                           21
# ...
